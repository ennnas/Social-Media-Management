# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math

def sigma1(x):
    return (1/(1+np.emath.power(np.pi , -x)))

def sigma2(x,w):
    z=np.dot(w,x)
    return (1/(1+np.exp(-z)))

# %%
x = np.arange(-20,20,0.5)
plt.plot(x,sigma1(x))

# %%
w=[3,5]
x=[np.arange(-20,20,0.5),np.arange(-20,20,0.5)]
plt.plot(np.dot(w,x),sigma2(x,w))

# %%
plt.plot?
